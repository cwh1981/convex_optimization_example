# %% [markdown]
# https://convex-optimization-for-all.github.io/chapter04/
# Q1. 왜 inquality와 eqaulity의 수식이 같이 있어야 할까? convex 정의?
#
# x^3 - 3x => p*:-inifimum,
#
# 1/x => no optimal
#
# -logx => -infimum
#
# xlogx => p*:-1/e, x=1/e

# %% [markdown]
# implicit constraint
# log(bi - aTix) => log is postive.
#
# $$\log (\alpha \pm \beta)$$

# %%
# %%html
# <style>
# table {float:left}
# </style>
# $$
# \begin{aligned}
#     X_{opt} = \ &\text{argmin}_x \ f(x) \\
#     \text{subject to} \ g_{i}(x) &\leq 0, i = 1, .., m \\
#     h_{j}(x) &= 0, i = 1, .., r  \\
# \end{aligned}
# $$
# Q1. gx와 hx가 두개 존재하는 이유??
# <BR
#
# >$$f(tx + (1-t)y) < tf(x) + (1-t)f(y) \text{ where } 0 < t < 1, x \neq y, \text{ and } x, y \in \text{dom } f.$$
# Q2. 왜 equality가 없는데 값이 하나가 있을까??
# Out:
# <style>
# table {float:left}
# </style>
# $$
# \begin{aligned}
#     X_{opt} = \ &\text{argmin}_x \ f(x) \\
#     \text{subject to} \ g_{i}(x) &\leq 0, i = 1, .., m \\
#     h_{j}(x) &= 0, i = 1, .., r  \\
# \end{aligned}
# $$
# Q1. gx와 hx가 두개 존재하는 이유??
# <BR
#
# >$$f(tx + (1-t)y) < tf(x) + (1-t)f(y) \text{ where } 0 < t < 1, x \neq y, \text{ and } x, y \in \text{dom } f.$$
# Q2. 왜 equality가 없는데 값이 하나가 있을까??

# %% [markdown]
# ## Lasso 예제 필요
# ![image.png](attachment:image.png)

# %% [markdown]
# ## SVM 예제 필요
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 그리스 기호 확인
# https://ko.wikipedia.org/wiki/%EA%B7%B8%EB%A6%AC%EC%8A%A4_%EB%AC%B8%EC%9E%90

# %% [markdown]
# ## First order optimality condition
# https://convex-optimization-for-all.github.io/chapter04/2020/02/08/04_03_First_order_optimality_condition/
#
# ![image.png](attachment:image.png)
#
# minimal x의 조건은 y가 항상 x보다 왼쪽에 있어야 하고, 그래서 미분 가능한 f(x)는 -방향으로 진행해야 한다.

# %% [markdown]
# ## Partial optimization
# ???

# %% [markdown]
# ## Transformations and change of variables
# 문제를 쉽게 풀수 있는 방법

# %% [markdown]
# ## Eliminating equality constraints

# %% [markdown]
# ## Slack variales
# 여유 값을 두어서 convex한 문제로 변경
# 예제 필요

# %% [markdown]
# ## Relaxation
# ![image.png](attachment:image.png)
#
# ### pca
# ![image.png](attachment:image.png)
